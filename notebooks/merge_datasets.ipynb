# %%
import pandas as pd
import numpy as np
import os

# %%
feature_path = '../data/interim'
meta_data_path = '../data/video_meta_data'

# features
yt = pd.read_pickle(os.path.join(feature_path, 'features_youtube.pkl'))
clin = pd.read_pickle(os.path.join(feature_path, 'features_clinical.pkl'))

# meta data youtube
# id: unique id per infant
# rated age in total weeks and total months
meta_data_yt = pd.read_pickle(os.path.join(meta_data_path, 'meta_data_yt.pkl'))
meta_data_yt['video'] = meta_data_yt.Video.str[:-4]
meta_data_yt = meta_data_yt.drop(['total_months','Video','rater', 'Months', 'Weeks', 'Unnamed: 0'],axis=1)
meta_data_yt.columns = ['age_in_weeks', 'video']
id_yt = pd.read_pickle(os.path.join(meta_data_path,'infant_id_yt.pkl'))
id_yt['video'] = id_yt.video.str[:-4]
meta_data_yt = pd.merge(meta_data_yt,id_yt, on='video', how='outer')
yt = pd.merge(yt,meta_data_yt, on='video', how='inner')

# meta data clinical
# id: unique id per infant
# age (corrected and chronological), BINS, risk, pre-term
meta_data_clin = pd.read_pickle(os.path.join(meta_data_path,'meta_data_clin.pkl'))
info_series = pd.Series([i.replace('-', '_').split('_') for i in clin.video])
info_df = info_series.apply(pd.Series)
info_df.columns = ['dum', 'infant', 'session', 'trial', 'GP', 'edited']
clin[['infant', 'session', 'trial']] = info_df[['infant', 'session', 'trial']]

# add meta-data columns:
# category: label 0 -yt, 1 -clin
# risk: 0 -yt, >0 -clin
# manual input of missing risk data based on input from Dr. Prosser. Infants: 28,29,32,33 are all high risk (corrected risk)

# merge meta-data and features dataframe
clin['category'] = 1
yt['category'] = 0
yt['risk'] = 0
yt['infant'] = 'yt_'+yt['infant_id'].astype(int).astype(str)
meta_data_clin['risk'] = meta_data_clin['Risk_low0_mod1_high2_corr'] # corrected risk for preterm infants
meta_data_clin.loc[meta_data_clin.risk.isnull(),'risk'] = meta_data_clin.loc[meta_data_clin.risk.isnull(), 'Risk_low0_mod1_high2_chron'] # chronological risk for term infants
meta_data_clin['risk'] = meta_data_clin['risk']+1
meta_data_clin['chron_age'] = meta_data_clin['Months_chron']*4 + meta_data_clin['Days_chron']/7 # chronological age for term infants
meta_data_clin['age_in_weeks'] = meta_data_clin['Months_corr']*4 + meta_data_clin['Days_corr']/7 # corrected age for preterm infants
meta_data_clin.loc[meta_data_clin.age_in_weeks.isnull(),'age_in_weeks'] = meta_data_clin.loc[meta_data_clin.age_in_weeks.isnull(), 'chron_age']
meta_data_clin = meta_data_clin[['infant','session' ,'risk', 'age_in_weeks']]
meta_data_clin.loc[np.isin(meta_data_clin.infant, np.array([28,29,32,33])),'risk'] = 3 # Dr. Prosser. Infants: 28,29,32,33 are all high risk (corrected risk)
clin['infant'] = clin.infant.astype(int)
clin['session'] = clin.session.astype(int)
clin = pd.merge(clin, meta_data_clin, on=['infant', 'session'], how='inner')
clin['infant'] = 'clin_'+clin['infant'].astype(str)+'_'+clin['age_in_weeks'].astype(int).astype(str)

clin = clin.drop(['session', 'trial'], axis=1)
yt = yt.drop('infant_id', axis=1)

features = clin.append(yt)
features = features.set_index(['video','category', 'infant', 'age_in_weeks', 'risk']).reset_index()
# average across rows for same infant
features = features.groupby('infant').mean().reset_index()

id_vars = ['infant', 'category','age_in_weeks', 'risk']
# pivot dataframe
features = pd.melt(features, id_vars=id_vars, var_name="feature", value_name="Value")

# average across left and right sides: split column into feature, part, side
# add age bracket

# save

# compute surprise
# get stats for each group


features
# Out:
#           infant  category  age_in_weeks  risk                   feature  \
# 0     clin_11_16         1     16.000000   1.0      IQR_acc_angle_LElbow
# 1     clin_15_10         1     10.000000   2.0      IQR_acc_angle_LElbow
# 2     clin_16_22         1     22.000000   3.0      IQR_acc_angle_LElbow
# 3     clin_17_15         1     15.000000   1.0      IQR_acc_angle_LElbow
# 4     clin_18_16         1     16.571429   1.0      IQR_acc_angle_LElbow
# 5     clin_19_26         1     26.000000   3.0      IQR_acc_angle_LElbow
# 6     clin_20_18         1     18.000000   3.0      IQR_acc_angle_LElbow
# 7     clin_23_46         1     46.000000   2.0      IQR_acc_angle_LElbow
# 8     clin_24_17         1     17.142857   2.0      IQR_acc_angle_LElbow
# 9     clin_25_31         1     31.000000   1.0      IQR_acc_angle_LElbow
# 10    clin_26_38         1     38.000000   2.0      IQR_acc_angle_LElbow
# 11    clin_27_29         1     29.000000   1.0      IQR_acc_angle_LElbow
# 12     clin_28_8         1      8.000000   3.0      IQR_acc_angle_LElbow
# 13    clin_29_20         1     20.000000   3.0      IQR_acc_angle_LElbow
# 14    clin_30_20         1     20.857143   3.0      IQR_acc_angle_LElbow
# 15    clin_31_16         1     16.000000   2.0      IQR_acc_angle_LElbow
# 16     clin_32_6         1      6.000000   3.0      IQR_acc_angle_LElbow
# 17     clin_33_4         1      4.000000   3.0      IQR_acc_angle_LElbow
# 18    clin_34_22         1     22.000000   3.0      IQR_acc_angle_LElbow
# 19     clin_6_16         1     16.000000   2.0      IQR_acc_angle_LElbow
# 20     clin_7_27         1     27.142857   2.0      IQR_acc_angle_LElbow
# 21     clin_8_18         1     18.285714   2.0      IQR_acc_angle_LElbow
# 22     clin_9_21         1     21.333333   2.0      IQR_acc_angle_LElbow
# 23          yt_0         0     10.000000   0.0      IQR_acc_angle_LElbow
# 24          yt_1         0      3.000000   0.0      IQR_acc_angle_LElbow
# 25         yt_10         0      4.500000   0.0      IQR_acc_angle_LElbow
# 26         yt_11         0     12.000000   0.0      IQR_acc_angle_LElbow
# 27         yt_12         0     14.166667   0.0      IQR_acc_angle_LElbow
# 28         yt_13         0     12.000000   0.0      IQR_acc_angle_LElbow
# 29         yt_14         0      3.500000   0.0      IQR_acc_angle_LElbow
# ...          ...       ...           ...   ...                       ...
# 9906       yt_59         0      2.000000   0.0  variance_angle_RShoulder
# 9907        yt_6         0     18.000000   0.0  variance_angle_RShoulder
# 9908       yt_60         0      2.000000   0.0  variance_angle_RShoulder
# 9909       yt_61         0     12.000000   0.0  variance_angle_RShoulder
# 9910       yt_62         0     12.000000   0.0  variance_angle_RShoulder
# 9911       yt_63         0     16.000000   0.0  variance_angle_RShoulder
# 9912       yt_64         0     16.000000   0.0  variance_angle_RShoulder
# 9913       yt_65         0      8.000000   0.0  variance_angle_RShoulder
# 9914       yt_66         0      8.000000   0.0  variance_angle_RShoulder
# 9915       yt_67         0     16.000000   0.0  variance_angle_RShoulder
# 9916       yt_68         0     16.000000   0.0  variance_angle_RShoulder
# 9917       yt_69         0     24.000000   0.0  variance_angle_RShoulder
# 9918        yt_7         0      1.500000   0.0  variance_angle_RShoulder
# 9919       yt_70         0     24.000000   0.0  variance_angle_RShoulder
# 9920       yt_71         0      1.000000   0.0  variance_angle_RShoulder
# 9921       yt_72         0      1.000000   0.0  variance_angle_RShoulder
# 9922       yt_73         0      6.000000   0.0  variance_angle_RShoulder
# 9923       yt_74         0     20.000000   0.0  variance_angle_RShoulder
# 9924       yt_75         0      4.000000   0.0  variance_angle_RShoulder
# 9925       yt_76         0     16.000000   0.0  variance_angle_RShoulder
# 9926       yt_77         0      8.000000   0.0  variance_angle_RShoulder
# 9927       yt_78         0     16.000000   0.0  variance_angle_RShoulder
# 9928       yt_79         0     16.000000   0.0  variance_angle_RShoulder
# 9929        yt_8         0     10.000000   0.0  variance_angle_RShoulder
# 9930       yt_80         0     20.000000   0.0  variance_angle_RShoulder
# 9931       yt_81         0     20.000000   0.0  variance_angle_RShoulder
# 9932       yt_82         0     20.000000   0.0  variance_angle_RShoulder
# 9933       yt_83         0     12.000000   0.0  variance_angle_RShoulder
# 9934       yt_84         0      2.000000   0.0  variance_angle_RShoulder
# 9935        yt_9         0     12.000000   0.0  variance_angle_RShoulder
#
#            Value
# 0      52.574287
# 1      42.940209
# 2      22.701369
# 3      23.426590
# 4      35.314280
# 5      80.343646
# 6      58.577384
# 7      34.527306
# 8      42.237291
# 9      38.058047
# 10     54.414029
# 11     31.313330
# 12     49.926604
# 13     40.010827
# 14     61.571332
# 15     57.659591
# 16    254.758552
# 17     97.337347
# 18     61.626142
# 19     34.797895
# 20     14.146598
# 21     58.882486
# 22     86.272020
# 23    209.318761
# 24     88.838204
# 25     43.550821
# 26    136.400187
# 27    171.320132
# 28     61.557992
# 29     61.017519
# ...          ...
# 9906    4.274067
# 9907   13.942751
# 9908    4.759154
# 9909    1.783642
# 9910    1.224922
# 9911    0.930594
# 9912    1.566375
# 9913    0.982696
# 9914    0.492633
# 9915    0.559167
# 9916    2.462211
# 9917    8.348267
# 9918    0.899847
# 9919    0.110706
# 9920    2.936151
# 9921    2.699229
# 9922    2.497403
# 9923    0.300475
# 9924    3.135274
# 9925    0.367210
# 9926    0.530375
# 9927    0.283527
# 9928    0.132149
# 9929    0.376281
# 9930    0.401591
# 9931    4.676162
# 9932    0.367497
# 9933    4.807023
# 9934   12.350089
# 9935    2.817184
#
# [9936 rows x 6 columns]
